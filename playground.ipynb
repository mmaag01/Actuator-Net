# %%
# Refit scaler_X and scaler_y
import sys; sys.path.insert(0, '.')
from dataset import build_datasets
build_datasets(save_scalers=True)
print('Done — scaler_X.pkl and scaler_y.pkl regenerated.')
# Out:
# Loading 5 PLC files from Main
# Loading 5 PMS files from Main
# Loading 5 TMS files from Main
# Loading 7 tStep files from Main
# Done — scaler_X.pkl and scaler_y.pkl regenerated.
